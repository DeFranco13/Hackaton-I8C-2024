# %%
import pandas as pd
from datetime import datetime
import numpy as np
import json

# Data laden
file_path = '../../dataset.json'  # Ensure the correct path to the dataset
data = pd.read_json(file_path)

# Extract 'nurseLocation', 'patientLocation', and 'service' from the 'visit' dictionary
data['nurse_latitude'] = data['visit'].apply(lambda x: x['nurseLocation']['latitude'])
data['nurse_longitude'] = data['visit'].apply(lambda x: x['nurseLocation']['longtitude'])
data['patient_latitude'] = data['visit'].apply(lambda x: x['patientLocation']['latitude'])
data['patient_longitude'] = data['visit'].apply(lambda x: x['patientLocation']['longtitude'])
data['service'] = data['visit'].apply(lambda x: x['service'])

# Frauderisico beoordelen
def fraud_risk(row, group, same_day_threshold=2, service_ratio_threshold=0.75):
    same_day_service_count = group[(group['visit_day'] == row['visit_day']) & (group['service'] == row['service'])].shape[0]
    if same_day_service_count > same_day_threshold:
        return "High Risk"
    service_ratio = (group['service'] == row['service']).mean()
    if service_ratio > service_ratio_threshold:
        return "Medium Risk"
    return "Low Risk"

# Data voorbereiden voor risicoberekening
data['visit_timestamp'] = pd.to_datetime(data['visit_timestamp'])
data['visit_day'] = data['visit_timestamp'].dt.date

grouped = data.groupby('rijksregisterNurse')
data['Fraud Risk'] = data.apply(lambda row: fraud_risk(row, grouped.get_group(row['rijksregisterNurse'])), axis=1)

# Filter out only high and medium risk entries
filtered_data = data[data['Fraud Risk'].isin(['High Risk', 'Medium Risk'])]

# Convert visit_timestamp and visit_day to string for JSON serialization
filtered_data['visit_timestamp'] = filtered_data['visit_timestamp'].astype(str)
filtered_data['visit_day'] = filtered_data['visit_day'].astype(str)

# Convert filtered data to list of dictionaries
result = filtered_data.to_dict(orient='records')

# Print the results
print(json.dumps(result, indent=4))
# Out:
# [
#     {
#         "rijksregisterPatient": 48485354849,
#         "rijksregisterNurse": 23763617294,
#         "visit": {
#             "id": 4395,
#             "visitAmounts": 2,
#             "duration": "SIX_MONTHS",
#             "service": "DENTAL_CARE",
#             "nurseLocation": {
#                 "latitude": 51.243491,
#                 "longtitude": 3.841391
#             },
#             "patientLocation": {
#                 "latitude": 50.540657,
#                 "longtitude": 4.778784
#             }
#         },
#         "visit_timestamp": "2024-06-21 23:59:24+00:00",
#         "driveTime": 8,
#         "distance": 1.005,
#         "nurse_latitude": 51.243491,
#         "nurse_longitude": 3.841391,
#         "patient_latitude": 50.540657,
#         "patient_longitude": 4.778784,
#         "service": "DENTAL_CARE",
#         "visit_day": "2024-06-21",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 62554883857,
#         "rijksregisterNurse": 33429776280,
#         "visit": {
#             "id": 1456,
#             "visitAmounts": 4,
#             "duration": "TWELVE_MONTHS",
#             "service": "VITAL_SIGN_MONITORING",
#             "nurseLocation": {
#                 "latitude": 49.516378,
#                 "longtitude": 4.242347
#             },
#             "patientLocation": {
#                 "latitude": 51.213423,
#                 "longtitude": 2.651325
#             }
#         },
#         "visit_timestamp": "2024-06-08 01:56:12+00:00",
#         "driveTime": 19,
#         "distance": 2.757,
#         "nurse_latitude": 49.516378,
#         "nurse_longitude": 4.242347,
#         "patient_latitude": 51.213423,
#         "patient_longitude": 2.651325,
#         "service": "VITAL_SIGN_MONITORING",
#         "visit_day": "2024-06-08",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 94196499554,
#         "rijksregisterNurse": 30909258976,
#         "visit": {
#             "id": 6622,
#             "visitAmounts": 5,
#             "duration": "FIVE_MONTHS",
#             "service": "BATHING",
#             "nurseLocation": {
#                 "latitude": 50.411202,
#                 "longtitude": 3.08675
#             },
#             "patientLocation": {
#                 "latitude": 51.114268,
#                 "longtitude": 4.955355
#             }
#         },
#         "visit_timestamp": "2024-10-20 00:58:47+00:00",
#         "driveTime": 39,
#         "distance": 1.432,
#         "nurse_latitude": 50.411202,
#         "nurse_longitude": 3.08675,
#         "patient_latitude": 51.114268,
#         "patient_longitude": 4.955355,
#         "service": "BATHING",
#         "visit_day": "2024-10-20",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 28858842488,
#         "rijksregisterNurse": 74189801771,
#         "visit": {
#             "id": 4543,
#             "visitAmounts": 5,
#             "duration": "TWO_MONTHS",
#             "service": "WALKING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 50.372754,
#                 "longtitude": 5.481052
#             },
#             "patientLocation": {
#                 "latitude": 51.399684,
#                 "longtitude": 3.369252
#             }
#         },
#         "visit_timestamp": "2024-04-05 22:58:27+00:00",
#         "driveTime": 40,
#         "distance": 4.335,
#         "nurse_latitude": 50.372754,
#         "nurse_longitude": 5.481052,
#         "patient_latitude": 51.399684,
#         "patient_longitude": 3.369252,
#         "service": "WALKING_ASSISTANCE",
#         "visit_day": "2024-04-05",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 86820122297,
#         "rijksregisterNurse": 25143544548,
#         "visit": {
#             "id": 3223,
#             "visitAmounts": 9,
#             "duration": "SIX_MONTHS",
#             "service": "PHYSICAL_THERAPY",
#             "nurseLocation": {
#                 "latitude": 51.135558,
#                 "longtitude": 5.546187
#             },
#             "patientLocation": {
#                 "latitude": 50.994801,
#                 "longtitude": 4.899326
#             }
#         },
#         "visit_timestamp": "2024-10-01 22:22:35+00:00",
#         "driveTime": 17,
#         "distance": 0.908,
#         "nurse_latitude": 51.135558,
#         "nurse_longitude": 5.546187,
#         "patient_latitude": 50.994801,
#         "patient_longitude": 4.899326,
#         "service": "PHYSICAL_THERAPY",
#         "visit_day": "2024-10-01",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 49425118651,
#         "rijksregisterNurse": 35664731752,
#         "visit": {
#             "id": 9475,
#             "visitAmounts": 2,
#             "duration": "FOUR_MONTHS",
#             "service": "NUTRITIONAL_SUPPORT",
#             "nurseLocation": {
#                 "latitude": 50.849592,
#                 "longtitude": 5.310377
#             },
#             "patientLocation": {
#                 "latitude": 50.645607,
#                 "longtitude": 5.596176
#             }
#         },
#         "visit_timestamp": "2024-10-02 22:12:51+00:00",
#         "driveTime": 44,
#         "distance": 2.428,
#         "nurse_latitude": 50.849592,
#         "nurse_longitude": 5.310377,
#         "patient_latitude": 50.645607,
#         "patient_longitude": 5.596176,
#         "service": "NUTRITIONAL_SUPPORT",
#         "visit_day": "2024-10-02",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 69570329119,
#         "rijksregisterNurse": 21822217635,
#         "visit": {
#             "id": 8424,
#             "visitAmounts": 9,
#             "duration": "NINE_MONTHS",
#             "service": "BATHING",
#             "nurseLocation": {
#                 "latitude": 50.924832,
#                 "longtitude": 4.633362
#             },
#             "patientLocation": {
#                 "latitude": 51.486447,
#                 "longtitude": 3.036563
#             }
#         },
#         "visit_timestamp": "2024-06-10 01:50:49+00:00",
#         "driveTime": 44,
#         "distance": 4.492,
#         "nurse_latitude": 50.924832,
#         "nurse_longitude": 4.633362,
#         "patient_latitude": 51.486447,
#         "patient_longitude": 3.036563,
#         "service": "BATHING",
#         "visit_day": "2024-06-10",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 35053754407,
#         "rijksregisterNurse": 12112154162,
#         "visit": {
#             "id": 9544,
#             "visitAmounts": 5,
#             "duration": "FIVE_MONTHS",
#             "service": "FEEDING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 51.264411,
#                 "longtitude": 5.953720000000001
#             },
#             "patientLocation": {
#                 "latitude": 51.153926,
#                 "longtitude": 4.467634
#             }
#         },
#         "visit_timestamp": "2024-02-17 22:50:39+00:00",
#         "driveTime": 47,
#         "distance": 4.577,
#         "nurse_latitude": 51.264411,
#         "nurse_longitude": 5.953720000000001,
#         "patient_latitude": 51.153926,
#         "patient_longitude": 4.467634,
#         "service": "FEEDING_ASSISTANCE",
#         "visit_day": "2024-02-17",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 42945141620,
#         "rijksregisterNurse": 52533717650,
#         "visit": {
#             "id": 2573,
#             "visitAmounts": 6,
#             "duration": "TEN_MONTHS",
#             "service": "FEEDING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 50.476795,
#                 "longtitude": 5.259452
#             },
#             "patientLocation": {
#                 "latitude": 50.263552,
#                 "longtitude": 4.688085
#             }
#         },
#         "visit_timestamp": "2024-04-09 23:13:05+00:00",
#         "driveTime": 50,
#         "distance": 2.219,
#         "nurse_latitude": 50.476795,
#         "nurse_longitude": 5.259452,
#         "patient_latitude": 50.263552,
#         "patient_longitude": 4.688085,
#         "service": "FEEDING_ASSISTANCE",
#         "visit_day": "2024-04-09",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 35692357248,
#         "rijksregisterNurse": 42657605936,
#         "visit": {
#             "id": 1132,
#             "visitAmounts": 10,
#             "duration": "ONE_MONTH",
#             "service": "PHYSICAL_THERAPY",
#             "nurseLocation": {
#                 "latitude": 50.08752,
#                 "longtitude": 4.105657
#             },
#             "patientLocation": {
#                 "latitude": 51.481532,
#                 "longtitude": 3.306673
#             }
#         },
#         "visit_timestamp": "2024-08-17 02:51:55+00:00",
#         "driveTime": 59,
#         "distance": 3.926,
#         "nurse_latitude": 50.08752,
#         "nurse_longitude": 4.105657,
#         "patient_latitude": 51.481532,
#         "patient_longitude": 3.306673,
#         "service": "PHYSICAL_THERAPY",
#         "visit_day": "2024-08-17",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 48534842967,
#         "rijksregisterNurse": 16350092877,
#         "visit": {
#             "id": 4143,
#             "visitAmounts": 10,
#             "duration": "EIGHT_MONTHS",
#             "service": "WALKING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 50.903316,
#                 "longtitude": 3.748426
#             },
#             "patientLocation": {
#                 "latitude": 51.270446,
#                 "longtitude": 4.844552
#             }
#         },
#         "visit_timestamp": "2024-12-12 11:17:11+00:00",
#         "driveTime": 35,
#         "distance": 2.555,
#         "nurse_latitude": 50.903316,
#         "nurse_longitude": 3.748426,
#         "patient_latitude": 51.270446,
#         "patient_longitude": 4.844552,
#         "service": "WALKING_ASSISTANCE",
#         "visit_day": "2024-12-12",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 60897837675,
#         "rijksregisterNurse": 38003929915,
#         "visit": {
#             "id": 5376,
#             "visitAmounts": 2,
#             "duration": "TWO_MONTHS",
#             "service": "BATHING",
#             "nurseLocation": {
#                 "latitude": 50.065099,
#                 "longtitude": 3.61591
#             },
#             "patientLocation": {
#                 "latitude": 49.817461,
#                 "longtitude": 3.908073
#             }
#         },
#         "visit_timestamp": "2024-11-17 06:22:24+00:00",
#         "driveTime": 17,
#         "distance": 4.965,
#         "nurse_latitude": 50.065099,
#         "nurse_longitude": 3.61591,
#         "patient_latitude": 49.817461,
#         "patient_longitude": 3.908073,
#         "service": "BATHING",
#         "visit_day": "2024-11-17",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 55951354144,
#         "rijksregisterNurse": 96877789195,
#         "visit": {
#             "id": 2369,
#             "visitAmounts": 3,
#             "duration": "ONE_MONTH",
#             "service": "PHYSICAL_THERAPY",
#             "nurseLocation": {
#                 "latitude": 51.25252,
#                 "longtitude": 2.542124
#             },
#             "patientLocation": {
#                 "latitude": 50.445947,
#                 "longtitude": 4.622763
#             }
#         },
#         "visit_timestamp": "2024-03-13 06:34:41+00:00",
#         "driveTime": 35,
#         "distance": 0.93,
#         "nurse_latitude": 51.25252,
#         "nurse_longitude": 2.542124,
#         "patient_latitude": 50.445947,
#         "patient_longitude": 4.622763,
#         "service": "PHYSICAL_THERAPY",
#         "visit_day": "2024-03-13",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 59090049861,
#         "rijksregisterNurse": 97604858892,
#         "visit": {
#             "id": 3961,
#             "visitAmounts": 4,
#             "duration": "NINE_MONTHS",
#             "service": "ADMINISTER_MEDICATION",
#             "nurseLocation": {
#                 "latitude": 49.640428,
#                 "longtitude": 3.290048
#             },
#             "patientLocation": {
#                 "latitude": 50.875314,
#                 "longtitude": 3.442323
#             }
#         },
#         "visit_timestamp": "2024-06-14 10:16:41+00:00",
#         "driveTime": 60,
#         "distance": 1.174,
#         "nurse_latitude": 49.640428,
#         "nurse_longitude": 3.290048,
#         "patient_latitude": 50.875314,
#         "patient_longitude": 3.442323,
#         "service": "ADMINISTER_MEDICATION",
#         "visit_day": "2024-06-14",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 26604292349,
#         "rijksregisterNurse": 90111527790,
#         "visit": {
#             "id": 3240,
#             "visitAmounts": 5,
#             "duration": "THREE_MONTHS",
#             "service": "ADMINISTER_MEDICATION",
#             "nurseLocation": {
#                 "latitude": 50.157744,
#                 "longtitude": 4.208532
#             },
#             "patientLocation": {
#                 "latitude": 51.229105,
#                 "longtitude": 5.439745
#             }
#         },
#         "visit_timestamp": "2024-08-01 19:28:00+00:00",
#         "driveTime": 41,
#         "distance": 1.605,
#         "nurse_latitude": 50.157744,
#         "nurse_longitude": 4.208532,
#         "patient_latitude": 51.229105,
#         "patient_longitude": 5.439745,
#         "service": "ADMINISTER_MEDICATION",
#         "visit_day": "2024-08-01",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 72863387545,
#         "rijksregisterNurse": 98991365043,
#         "visit": {
#             "id": 7501,
#             "visitAmounts": 7,
#             "duration": "NINE_MONTHS",
#             "service": "ADMINISTER_MEDICATION",
#             "nurseLocation": {
#                 "latitude": 49.857437,
#                 "longtitude": 4.518338
#             },
#             "patientLocation": {
#                 "latitude": 50.347963,
#                 "longtitude": 4.005278
#             }
#         },
#         "visit_timestamp": "2024-05-25 14:52:30+00:00",
#         "driveTime": 38,
#         "distance": 1.192,
#         "nurse_latitude": 49.857437,
#         "nurse_longitude": 4.518338,
#         "patient_latitude": 50.347963,
#         "patient_longitude": 4.005278,
#         "service": "ADMINISTER_MEDICATION",
#         "visit_day": "2024-05-25",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 68520646043,
#         "rijksregisterNurse": 13612614943,
#         "visit": {
#             "id": 4963,
#             "visitAmounts": 7,
#             "duration": "ONE_MONTH",
#             "service": "VITAL_SIGN_MONITORING",
#             "nurseLocation": {
#                 "latitude": 51.155451,
#                 "longtitude": 3.556566
#             },
#             "patientLocation": {
#                 "latitude": 50.527053,
#                 "longtitude": 4.843202
#             }
#         },
#         "visit_timestamp": "2024-03-03 20:06:05+00:00",
#         "driveTime": 20,
#         "distance": 1.7650000000000001,
#         "nurse_latitude": 51.155451,
#         "nurse_longitude": 3.556566,
#         "patient_latitude": 50.527053,
#         "patient_longitude": 4.843202,
#         "service": "VITAL_SIGN_MONITORING",
#         "visit_day": "2024-03-03",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 58174682940,
#         "rijksregisterNurse": 75859500364,
#         "visit": {
#             "id": 3150,
#             "visitAmounts": 10,
#             "duration": "THREE_MONTHS",
#             "service": "WALKING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 51.425776,
#                 "longtitude": 2.595932
#             },
#             "patientLocation": {
#                 "latitude": 51.495187,
#                 "longtitude": 3.501352
#             }
#         },
#         "visit_timestamp": "2024-05-14 22:51:22+00:00",
#         "driveTime": 37,
#         "distance": 2.31,
#         "nurse_latitude": 51.425776,
#         "nurse_longitude": 2.595932,
#         "patient_latitude": 51.495187,
#         "patient_longitude": 3.501352,
#         "service": "WALKING_ASSISTANCE",
#         "visit_day": "2024-05-14",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 28052478933,
#         "rijksregisterNurse": 13300811570,
#         "visit": {
#             "id": 7994,
#             "visitAmounts": 1,
#             "duration": "NINE_MONTHS",
#             "service": "FEEDING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 51.087857,
#                 "longtitude": 5.985678
#             },
#             "patientLocation": {
#                 "latitude": 49.838292,
#                 "longtitude": 5.094648
#             }
#         },
#         "visit_timestamp": "2024-09-02 07:28:14+00:00",
#         "driveTime": 18,
#         "distance": 2.356,
#         "nurse_latitude": 51.087857,
#         "nurse_longitude": 5.985678,
#         "patient_latitude": 49.838292,
#         "patient_longitude": 5.094648,
#         "service": "FEEDING_ASSISTANCE",
#         "visit_day": "2024-09-02",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 62231049549,
#         "rijksregisterNurse": 47690820841,
#         "visit": {
#             "id": 1561,
#             "visitAmounts": 7,
#             "duration": "TEN_MONTHS",
#             "service": "NUTRITIONAL_SUPPORT",
#             "nurseLocation": {
#                 "latitude": 49.883545,
#                 "longtitude": 3.841214
#             },
#             "patientLocation": {
#                 "latitude": 49.972283,
#                 "longtitude": 5.81218
#             }
#         },
#         "visit_timestamp": "2024-06-26 18:50:24+00:00",
#         "driveTime": 54,
#         "distance": 2.109,
#         "nurse_latitude": 49.883545,
#         "nurse_longitude": 3.841214,
#         "patient_latitude": 49.972283,
#         "patient_longitude": 5.81218,
#         "service": "NUTRITIONAL_SUPPORT",
#         "visit_day": "2024-06-26",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 49798963274,
#         "rijksregisterNurse": 47133574562,
#         "visit": {
#             "id": 3638,
#             "visitAmounts": 4,
#             "duration": "TWO_MONTHS",
#             "service": "PHYSICAL_THERAPY",
#             "nurseLocation": {
#                 "latitude": 50.071295,
#                 "longtitude": 5.9380749999999995
#             },
#             "patientLocation": {
#                 "latitude": 50.239379,
#                 "longtitude": 4.368542
#             }
#         },
#         "visit_timestamp": "2024-11-16 16:56:40+00:00",
#         "driveTime": 40,
#         "distance": 3.481,
#         "nurse_latitude": 50.071295,
#         "nurse_longitude": 5.9380749999999995,
#         "patient_latitude": 50.239379,
#         "patient_longitude": 4.368542,
#         "service": "PHYSICAL_THERAPY",
#         "visit_day": "2024-11-16",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 16385615034,
#         "rijksregisterNurse": 54761016795,
#         "visit": {
#             "id": 3035,
#             "visitAmounts": 2,
#             "duration": "TWO_MONTHS",
#             "service": "FEEDING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 50.147418,
#                 "longtitude": 5.249228
#             },
#             "patientLocation": {
#                 "latitude": 51.484411,
#                 "longtitude": 4.251422
#             }
#         },
#         "visit_timestamp": "2024-08-31 09:20:53+00:00",
#         "driveTime": 43,
#         "distance": 4.73,
#         "nurse_latitude": 50.147418,
#         "nurse_longitude": 5.249228,
#         "patient_latitude": 51.484411,
#         "patient_longitude": 4.251422,
#         "service": "FEEDING_ASSISTANCE",
#         "visit_day": "2024-08-31",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 18961403908,
#         "rijksregisterNurse": 87399877824,
#         "visit": {
#             "id": 6289,
#             "visitAmounts": 4,
#             "duration": "EIGHT_MONTHS",
#             "service": "VITAL_SIGN_MONITORING",
#             "nurseLocation": {
#                 "latitude": 50.888614,
#                 "longtitude": 3.255729
#             },
#             "patientLocation": {
#                 "latitude": 50.26061,
#                 "longtitude": 5.61795
#             }
#         },
#         "visit_timestamp": "2024-11-28 08:27:21+00:00",
#         "driveTime": 34,
#         "distance": 1.327,
#         "nurse_latitude": 50.888614,
#         "nurse_longitude": 3.255729,
#         "patient_latitude": 50.26061,
#         "patient_longitude": 5.61795,
#         "service": "VITAL_SIGN_MONITORING",
#         "visit_day": "2024-11-28",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 87493785789,
#         "rijksregisterNurse": 15078202877,
#         "visit": {
#             "id": 8047,
#             "visitAmounts": 5,
#             "duration": "TWO_MONTHS",
#             "service": "FEEDING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 49.667183,
#                 "longtitude": 3.287738
#             },
#             "patientLocation": {
#                 "latitude": 50.907247,
#                 "longtitude": 3.345651
#             }
#         },
#         "visit_timestamp": "2024-10-11 18:46:25+00:00",
#         "driveTime": 47,
#         "distance": 0.915,
#         "nurse_latitude": 49.667183,
#         "nurse_longitude": 3.287738,
#         "patient_latitude": 50.907247,
#         "patient_longitude": 3.345651,
#         "service": "FEEDING_ASSISTANCE",
#         "visit_day": "2024-10-11",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 45199094789,
#         "rijksregisterNurse": 53594179692,
#         "visit": {
#             "id": 5188,
#             "visitAmounts": 5,
#             "duration": "ONE_MONTH",
#             "service": "VITAL_SIGN_MONITORING",
#             "nurseLocation": {
#                 "latitude": 49.604734,
#                 "longtitude": 3.150738
#             },
#             "patientLocation": {
#                 "latitude": 49.895276,
#                 "longtitude": 5.5051179999999995
#             }
#         },
#         "visit_timestamp": "2024-01-25 16:27:14+00:00",
#         "driveTime": 39,
#         "distance": 1.755,
#         "nurse_latitude": 49.604734,
#         "nurse_longitude": 3.150738,
#         "patient_latitude": 49.895276,
#         "patient_longitude": 5.5051179999999995,
#         "service": "VITAL_SIGN_MONITORING",
#         "visit_day": "2024-01-25",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 55108473142,
#         "rijksregisterNurse": 77007721265,
#         "visit": {
#             "id": 6983,
#             "visitAmounts": 2,
#             "duration": "THREE_MONTHS",
#             "service": "VITAL_SIGN_MONITORING",
#             "nurseLocation": {
#                 "latitude": 50.713727,
#                 "longtitude": 2.863117
#             },
#             "patientLocation": {
#                 "latitude": 50.762631,
#                 "longtitude": 4.781271
#             }
#         },
#         "visit_timestamp": "2024-06-27 11:23:51+00:00",
#         "driveTime": 31,
#         "distance": 4.886,
#         "nurse_latitude": 50.713727,
#         "nurse_longitude": 2.863117,
#         "patient_latitude": 50.762631,
#         "patient_longitude": 4.781271,
#         "service": "VITAL_SIGN_MONITORING",
#         "visit_day": "2024-06-27",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 29603978401,
#         "rijksregisterNurse": 35401192893,
#         "visit": {
#             "id": 3624,
#             "visitAmounts": 5,
#             "duration": "ONE_MONTH",
#             "service": "WALKING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 50.156153,
#                 "longtitude": 4.501428
#             },
#             "patientLocation": {
#                 "latitude": 49.62781,
#                 "longtitude": 3.795014
#             }
#         },
#         "visit_timestamp": "2024-06-15 18:09:28+00:00",
#         "driveTime": 17,
#         "distance": 3.053,
#         "nurse_latitude": 50.156153,
#         "nurse_longitude": 4.501428,
#         "patient_latitude": 49.62781,
#         "patient_longitude": 3.795014,
#         "service": "WALKING_ASSISTANCE",
#         "visit_day": "2024-06-15",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 87567751124,
#         "rijksregisterNurse": 67499544825,
#         "visit": {
#             "id": 9059,
#             "visitAmounts": 5,
#             "duration": "EIGHT_MONTHS",
#             "service": "DENTAL_CARE",
#             "nurseLocation": {
#                 "latitude": 50.146424,
#                 "longtitude": 3.179608
#             },
#             "patientLocation": {
#                 "latitude": 50.504964,
#                 "longtitude": 3.113882
#             }
#         },
#         "visit_timestamp": "2024-01-04 22:38:50+00:00",
#         "driveTime": 21,
#         "distance": 2.656,
#         "nurse_latitude": 50.146424,
#         "nurse_longitude": 3.179608,
#         "patient_latitude": 50.504964,
#         "patient_longitude": 3.113882,
#         "service": "DENTAL_CARE",
#         "visit_day": "2024-01-04",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 14808367474,
#         "rijksregisterNurse": 74417830177,
#         "visit": {
#             "id": 2272,
#             "visitAmounts": 7,
#             "duration": "TWELVE_MONTHS",
#             "service": "BATHING",
#             "nurseLocation": {
#                 "latitude": 50.218262,
#                 "longtitude": 3.659802
#             },
#             "patientLocation": {
#                 "latitude": 49.936315,
#                 "longtitude": 5.443353
#             }
#         },
#         "visit_timestamp": "2024-05-19 06:56:00+00:00",
#         "driveTime": 43,
#         "distance": 1.8050000000000002,
#         "nurse_latitude": 50.218262,
#         "nurse_longitude": 3.659802,
#         "patient_latitude": 49.936315,
#         "patient_longitude": 5.443353,
#         "service": "BATHING",
#         "visit_day": "2024-05-19",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 61254359914,
#         "rijksregisterNurse": 11397918724,
#         "visit": {
#             "id": 8734,
#             "visitAmounts": 6,
#             "duration": "TWO_MONTHS",
#             "service": "BATHING",
#             "nurseLocation": {
#                 "latitude": 50.376098,
#                 "longtitude": 3.884953
#             },
#             "patientLocation": {
#                 "latitude": 49.89371,
#                 "longtitude": 3.5222059999999997
#             }
#         },
#         "visit_timestamp": "2024-12-23 18:20:46+00:00",
#         "driveTime": 48,
#         "distance": 0.8260000000000001,
#         "nurse_latitude": 50.376098,
#         "nurse_longitude": 3.884953,
#         "patient_latitude": 49.89371,
#         "patient_longitude": 3.5222059999999997,
#         "service": "BATHING",
#         "visit_day": "2024-12-23",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 63272966414,
#         "rijksregisterNurse": 60449324980,
#         "visit": {
#             "id": 7843,
#             "visitAmounts": 5,
#             "duration": "FIVE_MONTHS",
#             "service": "TEMPERATURE_MONITORING",
#             "nurseLocation": {
#                 "latitude": 50.336483,
#                 "longtitude": 4.988885
#             },
#             "patientLocation": {
#                 "latitude": 50.795016,
#                 "longtitude": 5.755408
#             }
#         },
#         "visit_timestamp": "2024-12-03 17:10:05+00:00",
#         "driveTime": 58,
#         "distance": 4.39,
#         "nurse_latitude": 50.336483,
#         "nurse_longitude": 4.988885,
#         "patient_latitude": 50.795016,
#         "patient_longitude": 5.755408,
#         "service": "TEMPERATURE_MONITORING",
#         "visit_day": "2024-12-03",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 57867541236,
#         "rijksregisterNurse": 30774876461,
#         "visit": {
#             "id": 5447,
#             "visitAmounts": 9,
#             "duration": "NINE_MONTHS",
#             "service": "DENTAL_CARE",
#             "nurseLocation": {
#                 "latitude": 50.620959,
#                 "longtitude": 5.145275
#             },
#             "patientLocation": {
#                 "latitude": 49.819172,
#                 "longtitude": 5.6014669999999995
#             }
#         },
#         "visit_timestamp": "2024-05-22 06:03:10+00:00",
#         "driveTime": 26,
#         "distance": 1.338,
#         "nurse_latitude": 50.620959,
#         "nurse_longitude": 5.145275,
#         "patient_latitude": 49.819172,
#         "patient_longitude": 5.6014669999999995,
#         "service": "DENTAL_CARE",
#         "visit_day": "2024-05-22",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 45919314563,
#         "rijksregisterNurse": 93636383050,
#         "visit": {
#             "id": 9401,
#             "visitAmounts": 3,
#             "duration": "FIVE_MONTHS",
#             "service": "PHYSICAL_THERAPY",
#             "nurseLocation": {
#                 "latitude": 51.429637,
#                 "longtitude": 2.810778
#             },
#             "patientLocation": {
#                 "latitude": 50.134193,
#                 "longtitude": 3.059603
#             }
#         },
#         "visit_timestamp": "2024-07-02 22:29:40+00:00",
#         "driveTime": 11,
#         "distance": 0.726,
#         "nurse_latitude": 51.429637,
#         "nurse_longitude": 2.810778,
#         "patient_latitude": 50.134193,
#         "patient_longitude": 3.059603,
#         "service": "PHYSICAL_THERAPY",
#         "visit_day": "2024-07-02",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 98292290159,
#         "rijksregisterNurse": 89146590450,
#         "visit": {
#             "id": 5019,
#             "visitAmounts": 8,
#             "duration": "TWELVE_MONTHS",
#             "service": "TEMPERATURE_MONITORING",
#             "nurseLocation": {
#                 "latitude": 51.245365,
#                 "longtitude": 5.3301169999999995
#             },
#             "patientLocation": {
#                 "latitude": 49.60745,
#                 "longtitude": 5.6064
#             }
#         },
#         "visit_timestamp": "2024-08-29 18:06:06+00:00",
#         "driveTime": 20,
#         "distance": 3.816,
#         "nurse_latitude": 51.245365,
#         "nurse_longitude": 5.3301169999999995,
#         "patient_latitude": 49.60745,
#         "patient_longitude": 5.6064,
#         "service": "TEMPERATURE_MONITORING",
#         "visit_day": "2024-08-29",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 20825017715,
#         "rijksregisterNurse": 65856175209,
#         "visit": {
#             "id": 4917,
#             "visitAmounts": 9,
#             "duration": "ONE_MONTH",
#             "service": "WALKING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 49.94053,
#                 "longtitude": 2.938663
#             },
#             "patientLocation": {
#                 "latitude": 50.84071,
#                 "longtitude": 3.5634449999999998
#             }
#         },
#         "visit_timestamp": "2024-12-13 10:48:58+00:00",
#         "driveTime": 43,
#         "distance": 3.467,
#         "nurse_latitude": 49.94053,
#         "nurse_longitude": 2.938663,
#         "patient_latitude": 50.84071,
#         "patient_longitude": 3.5634449999999998,
#         "service": "WALKING_ASSISTANCE",
#         "visit_day": "2024-12-13",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 51716829899,
#         "rijksregisterNurse": 62155835575,
#         "visit": {
#             "id": 1339,
#             "visitAmounts": 2,
#             "duration": "FOUR_MONTHS",
#             "service": "NUTRITIONAL_SUPPORT",
#             "nurseLocation": {
#                 "latitude": 51.075597,
#                 "longtitude": 5.371825
#             },
#             "patientLocation": {
#                 "latitude": 50.428113,
#                 "longtitude": 4.431177
#             }
#         },
#         "visit_timestamp": "2024-06-11 17:45:48+00:00",
#         "driveTime": 35,
#         "distance": 4.032,
#         "nurse_latitude": 51.075597,
#         "nurse_longitude": 5.371825,
#         "patient_latitude": 50.428113,
#         "patient_longitude": 4.431177,
#         "service": "NUTRITIONAL_SUPPORT",
#         "visit_day": "2024-06-11",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 78067091333,
#         "rijksregisterNurse": 75938545504,
#         "visit": {
#             "id": 4123,
#             "visitAmounts": 3,
#             "duration": "FOUR_MONTHS",
#             "service": "PHYSICAL_THERAPY",
#             "nurseLocation": {
#                 "latitude": 49.790553,
#                 "longtitude": 5.622641
#             },
#             "patientLocation": {
#                 "latitude": 49.784718,
#                 "longtitude": 4.883019
#             }
#         },
#         "visit_timestamp": "2024-06-03 16:41:25+00:00",
#         "driveTime": 21,
#         "distance": 0.845,
#         "nurse_latitude": 49.790553,
#         "nurse_longitude": 5.622641,
#         "patient_latitude": 49.784718,
#         "patient_longitude": 4.883019,
#         "service": "PHYSICAL_THERAPY",
#         "visit_day": "2024-06-03",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 54485203124,
#         "rijksregisterNurse": 78938483725,
#         "visit": {
#             "id": 1818,
#             "visitAmounts": 1,
#             "duration": "ONE_MONTH",
#             "service": "VITAL_SIGN_MONITORING",
#             "nurseLocation": {
#                 "latitude": 50.835848,
#                 "longtitude": 3.349526
#             },
#             "patientLocation": {
#                 "latitude": 49.589724,
#                 "longtitude": 5.105515
#             }
#         },
#         "visit_timestamp": "2024-08-07 22:35:04+00:00",
#         "driveTime": 41,
#         "distance": 0.738,
#         "nurse_latitude": 50.835848,
#         "nurse_longitude": 3.349526,
#         "patient_latitude": 49.589724,
#         "patient_longitude": 5.105515,
#         "service": "VITAL_SIGN_MONITORING",
#         "visit_day": "2024-08-07",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 49571887911,
#         "rijksregisterNurse": 26349192816,
#         "visit": {
#             "id": 1852,
#             "visitAmounts": 5,
#             "duration": "TWELVE_MONTHS",
#             "service": "DENTAL_CARE",
#             "nurseLocation": {
#                 "latitude": 50.985752,
#                 "longtitude": 5.724748
#             },
#             "patientLocation": {
#                 "latitude": 50.452441,
#                 "longtitude": 2.996629
#             }
#         },
#         "visit_timestamp": "2024-07-20 17:52:27+00:00",
#         "driveTime": 14,
#         "distance": 3.868,
#         "nurse_latitude": 50.985752,
#         "nurse_longitude": 5.724748,
#         "patient_latitude": 50.452441,
#         "patient_longitude": 2.996629,
#         "service": "DENTAL_CARE",
#         "visit_day": "2024-07-20",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 91256407831,
#         "rijksregisterNurse": 78551680554,
#         "visit": {
#             "id": 9675,
#             "visitAmounts": 2,
#             "duration": "FIVE_MONTHS",
#             "service": "WALKING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 49.640632,
#                 "longtitude": 4.571398
#             },
#             "patientLocation": {
#                 "latitude": 49.972149,
#                 "longtitude": 5.894011
#             }
#         },
#         "visit_timestamp": "2024-06-15 12:41:11+00:00",
#         "driveTime": 11,
#         "distance": 3.149,
#         "nurse_latitude": 49.640632,
#         "nurse_longitude": 4.571398,
#         "patient_latitude": 49.972149,
#         "patient_longitude": 5.894011,
#         "service": "WALKING_ASSISTANCE",
#         "visit_day": "2024-06-15",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 81600971452,
#         "rijksregisterNurse": 99526154753,
#         "visit": {
#             "id": 1658,
#             "visitAmounts": 3,
#             "duration": "EIGHT_MONTHS",
#             "service": "FEEDING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 49.556908,
#                 "longtitude": 5.858691
#             },
#             "patientLocation": {
#                 "latitude": 50.850113,
#                 "longtitude": 5.234895
#             }
#         },
#         "visit_timestamp": "2024-08-08 15:16:33+00:00",
#         "driveTime": 39,
#         "distance": 2.775,
#         "nurse_latitude": 49.556908,
#         "nurse_longitude": 5.858691,
#         "patient_latitude": 50.850113,
#         "patient_longitude": 5.234895,
#         "service": "FEEDING_ASSISTANCE",
#         "visit_day": "2024-08-08",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 63233240157,
#         "rijksregisterNurse": 35966969826,
#         "visit": {
#             "id": 4220,
#             "visitAmounts": 3,
#             "duration": "TEN_MONTHS",
#             "service": "DENTAL_CARE",
#             "nurseLocation": {
#                 "latitude": 51.45726,
#                 "longtitude": 2.898379
#             },
#             "patientLocation": {
#                 "latitude": 49.59696,
#                 "longtitude": 3.94569
#             }
#         },
#         "visit_timestamp": "2024-06-16 09:20:11+00:00",
#         "driveTime": 29,
#         "distance": 3.71,
#         "nurse_latitude": 51.45726,
#         "nurse_longitude": 2.898379,
#         "patient_latitude": 49.59696,
#         "patient_longitude": 3.94569,
#         "service": "DENTAL_CARE",
#         "visit_day": "2024-06-16",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 89187634597,
#         "rijksregisterNurse": 28378576606,
#         "visit": {
#             "id": 8734,
#             "visitAmounts": 2,
#             "duration": "FIVE_MONTHS",
#             "service": "BATHING",
#             "nurseLocation": {
#                 "latitude": 49.986974,
#                 "longtitude": 4.316998
#             },
#             "patientLocation": {
#                 "latitude": 50.702034,
#                 "longtitude": 3.05116
#             }
#         },
#         "visit_timestamp": "2024-05-12 10:11:29+00:00",
#         "driveTime": 14,
#         "distance": 3.249,
#         "nurse_latitude": 49.986974,
#         "nurse_longitude": 4.316998,
#         "patient_latitude": 50.702034,
#         "patient_longitude": 3.05116,
#         "service": "BATHING",
#         "visit_day": "2024-05-12",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 51826286468,
#         "rijksregisterNurse": 58146565480,
#         "visit": {
#             "id": 9788,
#             "visitAmounts": 8,
#             "duration": "TWELVE_MONTHS",
#             "service": "NUTRITIONAL_SUPPORT",
#             "nurseLocation": {
#                 "latitude": 50.611279,
#                 "longtitude": 5.312721
#             },
#             "patientLocation": {
#                 "latitude": 49.824536,
#                 "longtitude": 5.626262
#             }
#         },
#         "visit_timestamp": "2024-02-11 09:53:34+00:00",
#         "driveTime": 15,
#         "distance": 2.197,
#         "nurse_latitude": 50.611279,
#         "nurse_longitude": 5.312721,
#         "patient_latitude": 49.824536,
#         "patient_longitude": 5.626262,
#         "service": "NUTRITIONAL_SUPPORT",
#         "visit_day": "2024-02-11",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 21106107818,
#         "rijksregisterNurse": 62889996605,
#         "visit": {
#             "id": 4652,
#             "visitAmounts": 2,
#             "duration": "TEN_MONTHS",
#             "service": "FEEDING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 51.472658,
#                 "longtitude": 5.41103
#             },
#             "patientLocation": {
#                 "latitude": 51.121146,
#                 "longtitude": 5.055778
#             }
#         },
#         "visit_timestamp": "2024-06-30 08:23:02+00:00",
#         "driveTime": 21,
#         "distance": 1.475,
#         "nurse_latitude": 51.472658,
#         "nurse_longitude": 5.41103,
#         "patient_latitude": 51.121146,
#         "patient_longitude": 5.055778,
#         "service": "FEEDING_ASSISTANCE",
#         "visit_day": "2024-06-30",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 27115548196,
#         "rijksregisterNurse": 55378253285,
#         "visit": {
#             "id": 4479,
#             "visitAmounts": 2,
#             "duration": "ONE_MONTH",
#             "service": "NUTRITIONAL_SUPPORT",
#             "nurseLocation": {
#                 "latitude": 50.914235,
#                 "longtitude": 5.838938
#             },
#             "patientLocation": {
#                 "latitude": 50.257323,
#                 "longtitude": 5.023492
#             }
#         },
#         "visit_timestamp": "2024-12-13 17:24:53+00:00",
#         "driveTime": 8,
#         "distance": 1.15,
#         "nurse_latitude": 50.914235,
#         "nurse_longitude": 5.838938,
#         "patient_latitude": 50.257323,
#         "patient_longitude": 5.023492,
#         "service": "NUTRITIONAL_SUPPORT",
#         "visit_day": "2024-12-13",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 75761702505,
#         "rijksregisterNurse": 97035581220,
#         "visit": {
#             "id": 5470,
#             "visitAmounts": 3,
#             "duration": "ONE_MONTH",
#             "service": "ADMINISTER_MEDICATION",
#             "nurseLocation": {
#                 "latitude": 50.827181,
#                 "longtitude": 3.087084
#             },
#             "patientLocation": {
#                 "latitude": 49.724851,
#                 "longtitude": 3.626852
#             }
#         },
#         "visit_timestamp": "2024-09-13 16:22:21+00:00",
#         "driveTime": 10,
#         "distance": 0.789,
#         "nurse_latitude": 50.827181,
#         "nurse_longitude": 3.087084,
#         "patient_latitude": 49.724851,
#         "patient_longitude": 3.626852,
#         "service": "ADMINISTER_MEDICATION",
#         "visit_day": "2024-09-13",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 42271639769,
#         "rijksregisterNurse": 27244677758,
#         "visit": {
#             "id": 2144,
#             "visitAmounts": 6,
#             "duration": "SIX_MONTHS",
#             "service": "WALKING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 51.495529,
#                 "longtitude": 5.913271
#             },
#             "patientLocation": {
#                 "latitude": 51.456037,
#                 "longtitude": 2.604426
#             }
#         },
#         "visit_timestamp": "2024-09-16 11:56:37+00:00",
#         "driveTime": 21,
#         "distance": 2.277,
#         "nurse_latitude": 51.495529,
#         "nurse_longitude": 5.913271,
#         "patient_latitude": 51.456037,
#         "patient_longitude": 2.604426,
#         "service": "WALKING_ASSISTANCE",
#         "visit_day": "2024-09-16",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 98624416405,
#         "rijksregisterNurse": 35272839640,
#         "visit": {
#             "id": 8636,
#             "visitAmounts": 5,
#             "duration": "EIGHT_MONTHS",
#             "service": "ADMINISTER_MEDICATION",
#             "nurseLocation": {
#                 "latitude": 50.459683,
#                 "longtitude": 5.303071
#             },
#             "patientLocation": {
#                 "latitude": 50.756334,
#                 "longtitude": 4.163973
#             }
#         },
#         "visit_timestamp": "2024-05-09 19:40:20+00:00",
#         "driveTime": 18,
#         "distance": 0.927,
#         "nurse_latitude": 50.459683,
#         "nurse_longitude": 5.303071,
#         "patient_latitude": 50.756334,
#         "patient_longitude": 4.163973,
#         "service": "ADMINISTER_MEDICATION",
#         "visit_day": "2024-05-09",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 13120449102,
#         "rijksregisterNurse": 84591309733,
#         "visit": {
#             "id": 6447,
#             "visitAmounts": 5,
#             "duration": "TWELVE_MONTHS",
#             "service": "FEEDING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 50.621457,
#                 "longtitude": 5.843469
#             },
#             "patientLocation": {
#                 "latitude": 51.238211,
#                 "longtitude": 3.395915
#             }
#         },
#         "visit_timestamp": "2024-06-04 11:45:13+00:00",
#         "driveTime": 44,
#         "distance": 4.684,
#         "nurse_latitude": 50.621457,
#         "nurse_longitude": 5.843469,
#         "patient_latitude": 51.238211,
#         "patient_longitude": 3.395915,
#         "service": "FEEDING_ASSISTANCE",
#         "visit_day": "2024-06-04",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 51439098048,
#         "rijksregisterNurse": 37648587828,
#         "visit": {
#             "id": 4232,
#             "visitAmounts": 8,
#             "duration": "TEN_MONTHS",
#             "service": "PHYSICAL_THERAPY",
#             "nurseLocation": {
#                 "latitude": 50.48578,
#                 "longtitude": 2.746669
#             },
#             "patientLocation": {
#                 "latitude": 49.658476,
#                 "longtitude": 2.929497
#             }
#         },
#         "visit_timestamp": "2024-09-22 08:10:30+00:00",
#         "driveTime": 5,
#         "distance": 1.983,
#         "nurse_latitude": 50.48578,
#         "nurse_longitude": 2.746669,
#         "patient_latitude": 49.658476,
#         "patient_longitude": 2.929497,
#         "service": "PHYSICAL_THERAPY",
#         "visit_day": "2024-09-22",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 37245805382,
#         "rijksregisterNurse": 71986852192,
#         "visit": {
#             "id": 1694,
#             "visitAmounts": 2,
#             "duration": "EIGHT_MONTHS",
#             "service": "WALKING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 50.647867,
#                 "longtitude": 5.438067
#             },
#             "patientLocation": {
#                 "latitude": 51.017173,
#                 "longtitude": 2.500969
#             }
#         },
#         "visit_timestamp": "2024-08-16 19:19:50+00:00",
#         "driveTime": 23,
#         "distance": 4.047,
#         "nurse_latitude": 50.647867,
#         "nurse_longitude": 5.438067,
#         "patient_latitude": 51.017173,
#         "patient_longitude": 2.500969,
#         "service": "WALKING_ASSISTANCE",
#         "visit_day": "2024-08-16",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 62655733187,
#         "rijksregisterNurse": 11235185470,
#         "visit": {
#             "id": 4111,
#             "visitAmounts": 8,
#             "duration": "THREE_MONTHS",
#             "service": "ADMINISTER_MEDICATION",
#             "nurseLocation": {
#                 "latitude": 50.168145,
#                 "longtitude": 5.38213
#             },
#             "patientLocation": {
#                 "latitude": 50.530045,
#                 "longtitude": 5.413712
#             }
#         },
#         "visit_timestamp": "2024-08-16 16:32:08+00:00",
#         "driveTime": 40,
#         "distance": 1.43,
#         "nurse_latitude": 50.168145,
#         "nurse_longitude": 5.38213,
#         "patient_latitude": 50.530045,
#         "patient_longitude": 5.413712,
#         "service": "ADMINISTER_MEDICATION",
#         "visit_day": "2024-08-16",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 59341056218,
#         "rijksregisterNurse": 14712886001,
#         "visit": {
#             "id": 4290,
#             "visitAmounts": 9,
#             "duration": "TEN_MONTHS",
#             "service": "BATHING",
#             "nurseLocation": {
#                 "latitude": 50.453717,
#                 "longtitude": 2.931634
#             },
#             "patientLocation": {
#                 "latitude": 50.373967,
#                 "longtitude": 4.925944
#             }
#         },
#         "visit_timestamp": "2024-02-06 19:35:16+00:00",
#         "driveTime": 18,
#         "distance": 4.905,
#         "nurse_latitude": 50.453717,
#         "nurse_longitude": 2.931634,
#         "patient_latitude": 50.373967,
#         "patient_longitude": 4.925944,
# ...
#         "rijksregisterNurse": 85213729155,
#         "visit": {
#             "id": 7413,
#             "visitAmounts": 8,
#             "duration": "FOUR_MONTHS",
#             "service": "FEEDING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 50.740436,
#                 "longtitude": 5.769434
#             },
#             "patientLocation": {
#                 "latitude": 49.534615,
#                 "longtitude": 3.983609
#             }
#         },
#         "visit_timestamp": "2024-06-23 17:34:51+00:00",
#         "driveTime": 53,
#         "distance": 3.985,
#         "nurse_latitude": 50.740436,
#         "nurse_longitude": 5.769434,
#         "patient_latitude": 49.534615,
#         "patient_longitude": 3.983609,
#         "service": "FEEDING_ASSISTANCE",
#         "visit_day": "2024-06-23",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 29886394711,
#         "rijksregisterNurse": 48195111343,
#         "visit": {
#             "id": 9381,
#             "visitAmounts": 1,
#             "duration": "ONE_MONTH",
#             "service": "BATHING",
#             "nurseLocation": {
#                 "latitude": 50.32671,
#                 "longtitude": 3.013691
#             },
#             "patientLocation": {
#                 "latitude": 49.521621,
#                 "longtitude": 5.618417
#             }
#         },
#         "visit_timestamp": "2024-09-04 07:04:53+00:00",
#         "driveTime": 55,
#         "distance": 2.484,
#         "nurse_latitude": 50.32671,
#         "nurse_longitude": 3.013691,
#         "patient_latitude": 49.521621,
#         "patient_longitude": 5.618417,
#         "service": "BATHING",
#         "visit_day": "2024-09-04",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 67275553792,
#         "rijksregisterNurse": 35561885726,
#         "visit": {
#             "id": 6353,
#             "visitAmounts": 2,
#             "duration": "TWELVE_MONTHS",
#             "service": "FEEDING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 50.650786,
#                 "longtitude": 2.569349
#             },
#             "patientLocation": {
#                 "latitude": 50.338101,
#                 "longtitude": 4.704464
#             }
#         },
#         "visit_timestamp": "2024-01-05 13:20:37+00:00",
#         "driveTime": 58,
#         "distance": 3.535,
#         "nurse_latitude": 50.650786,
#         "nurse_longitude": 2.569349,
#         "patient_latitude": 50.338101,
#         "patient_longitude": 4.704464,
#         "service": "FEEDING_ASSISTANCE",
#         "visit_day": "2024-01-05",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 22254655189,
#         "rijksregisterNurse": 93987838618,
#         "visit": {
#             "id": 6703,
#             "visitAmounts": 9,
#             "duration": "TEN_MONTHS",
#             "service": "DENTAL_CARE",
#             "nurseLocation": {
#                 "latitude": 51.255168,
#                 "longtitude": 4.745402
#             },
#             "patientLocation": {
#                 "latitude": 51.246847,
#                 "longtitude": 3.300253
#             }
#         },
#         "visit_timestamp": "2024-09-23 22:36:49+00:00",
#         "driveTime": 59,
#         "distance": 4.096,
#         "nurse_latitude": 51.255168,
#         "nurse_longitude": 4.745402,
#         "patient_latitude": 51.246847,
#         "patient_longitude": 3.300253,
#         "service": "DENTAL_CARE",
#         "visit_day": "2024-09-23",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 57077890356,
#         "rijksregisterNurse": 35856315097,
#         "visit": {
#             "id": 4759,
#             "visitAmounts": 7,
#             "duration": "THREE_MONTHS",
#             "service": "ADMINISTER_MEDICATION",
#             "nurseLocation": {
#                 "latitude": 50.796914,
#                 "longtitude": 3.836029
#             },
#             "patientLocation": {
#                 "latitude": 49.569775,
#                 "longtitude": 2.540926
#             }
#         },
#         "visit_timestamp": "2024-09-07 16:28:49+00:00",
#         "driveTime": 11,
#         "distance": 2.496,
#         "nurse_latitude": 50.796914,
#         "nurse_longitude": 3.836029,
#         "patient_latitude": 49.569775,
#         "patient_longitude": 2.540926,
#         "service": "ADMINISTER_MEDICATION",
#         "visit_day": "2024-09-07",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 84157359485,
#         "rijksregisterNurse": 18821869559,
#         "visit": {
#             "id": 4615,
#             "visitAmounts": 5,
#             "duration": "FOUR_MONTHS",
#             "service": "ADMINISTER_MEDICATION",
#             "nurseLocation": {
#                 "latitude": 51.138412,
#                 "longtitude": 4.947795
#             },
#             "patientLocation": {
#                 "latitude": 50.219342,
#                 "longtitude": 2.85587
#             }
#         },
#         "visit_timestamp": "2024-08-10 22:06:49+00:00",
#         "driveTime": 10,
#         "distance": 4.853,
#         "nurse_latitude": 51.138412,
#         "nurse_longitude": 4.947795,
#         "patient_latitude": 50.219342,
#         "patient_longitude": 2.85587,
#         "service": "ADMINISTER_MEDICATION",
#         "visit_day": "2024-08-10",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 29851272935,
#         "rijksregisterNurse": 53616740265,
#         "visit": {
#             "id": 4842,
#             "visitAmounts": 9,
#             "duration": "TWELVE_MONTHS",
#             "service": "FEEDING_ASSISTANCE",
#             "nurseLocation": {
#                 "latitude": 50.952931,
#                 "longtitude": 3.650683
#             },
#             "patientLocation": {
#                 "latitude": 51.429451,
#                 "longtitude": 3.456299
#             }
#         },
#         "visit_timestamp": "2024-10-28 18:57:30+00:00",
#         "driveTime": 54,
#         "distance": 2.058,
#         "nurse_latitude": 50.952931,
#         "nurse_longitude": 3.650683,
#         "patient_latitude": 51.429451,
#         "patient_longitude": 3.456299,
#         "service": "FEEDING_ASSISTANCE",
#         "visit_day": "2024-10-28",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 40308152011,
#         "rijksregisterNurse": 36215930531,
#         "visit": {
#             "id": 4590,
#             "visitAmounts": 1,
#             "duration": "FOUR_MONTHS",
#             "service": "VITAL_SIGN_MONITORING",
#             "nurseLocation": {
#                 "latitude": 50.692182,
#                 "longtitude": 3.656809
#             },
#             "patientLocation": {
#                 "latitude": 51.004269,
#                 "longtitude": 2.816039
#             }
#         },
#         "visit_timestamp": "2024-04-22 17:43:41+00:00",
#         "driveTime": 7,
#         "distance": 3.879,
#         "nurse_latitude": 50.692182,
#         "nurse_longitude": 3.656809,
#         "patient_latitude": 51.004269,
#         "patient_longitude": 2.816039,
#         "service": "VITAL_SIGN_MONITORING",
#         "visit_day": "2024-04-22",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 63948482129,
#         "rijksregisterNurse": 89973963475,
#         "visit": {
#             "id": 8346,
#             "visitAmounts": 7,
#             "duration": "THREE_MONTHS",
#             "service": "DENTAL_CARE",
#             "nurseLocation": {
#                 "latitude": 51.271578,
#                 "longtitude": 4.948763
#             },
#             "patientLocation": {
#                 "latitude": 50.913863,
#                 "longtitude": 4.397938
#             }
#         },
#         "visit_timestamp": "2024-10-22 06:06:15+00:00",
#         "driveTime": 21,
#         "distance": 4.578,
#         "nurse_latitude": 51.271578,
#         "nurse_longitude": 4.948763,
#         "patient_latitude": 50.913863,
#         "patient_longitude": 4.397938,
#         "service": "DENTAL_CARE",
#         "visit_day": "2024-10-22",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 53336886551,
#         "rijksregisterNurse": 24380394988,
#         "visit": {
#             "id": 9212,
#             "visitAmounts": 4,
#             "duration": "EIGHT_MONTHS",
#             "service": "VITAL_SIGN_MONITORING",
#             "nurseLocation": {
#                 "latitude": 51.170082,
#                 "longtitude": 5.26091
#             },
#             "patientLocation": {
#                 "latitude": 49.916317,
#                 "longtitude": 2.78992
#             }
#         },
#         "visit_timestamp": "2024-10-21 19:43:25+00:00",
#         "driveTime": 11,
#         "distance": 1.9460000000000002,
#         "nurse_latitude": 51.170082,
#         "nurse_longitude": 5.26091,
#         "patient_latitude": 49.916317,
#         "patient_longitude": 2.78992,
#         "service": "VITAL_SIGN_MONITORING",
#         "visit_day": "2024-10-21",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 70436645270,
#         "rijksregisterNurse": 74343692336,
#         "visit": {
#             "id": 6496,
#             "visitAmounts": 2,
#             "duration": "THREE_MONTHS",
#             "service": "VITAL_SIGN_MONITORING",
#             "nurseLocation": {
#                 "latitude": 50.419359,
#                 "longtitude": 4.061676
#             },
#             "patientLocation": {
#                 "latitude": 50.430942,
#                 "longtitude": 2.997473
#             }
#         },
#         "visit_timestamp": "2024-10-25 14:28:26+00:00",
#         "driveTime": 19,
#         "distance": 4.36,
#         "nurse_latitude": 50.419359,
#         "nurse_longitude": 4.061676,
#         "patient_latitude": 50.430942,
#         "patient_longitude": 2.997473,
#         "service": "VITAL_SIGN_MONITORING",
#         "visit_day": "2024-10-25",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 39992427172,
#         "rijksregisterNurse": 41816607226,
#         "visit": {
#             "id": 6707,
#             "visitAmounts": 2,
#             "duration": "FOUR_MONTHS",
#             "service": "VITAL_SIGN_MONITORING",
#             "nurseLocation": {
#                 "latitude": 50.920607,
#                 "longtitude": 5.130547
#             },
#             "patientLocation": {
#                 "latitude": 50.355538,
#                 "longtitude": 2.924967
#             }
#         },
#         "visit_timestamp": "2024-05-16 10:50:19+00:00",
#         "driveTime": 10,
#         "distance": 1.323,
#         "nurse_latitude": 50.920607,
#         "nurse_longitude": 5.130547,
#         "patient_latitude": 50.355538,
#         "patient_longitude": 2.924967,
#         "service": "VITAL_SIGN_MONITORING",
#         "visit_day": "2024-05-16",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 59771698466,
#         "rijksregisterNurse": 47246744105,
#         "visit": {
#             "id": 7472,
#             "visitAmounts": 1,
#             "duration": "FOUR_MONTHS",
#             "service": "BATHING",
#             "nurseLocation": {
#                 "latitude": 49.578164,
#                 "longtitude": 3.530603
#             },
#             "patientLocation": {
#                 "latitude": 51.474843,
#                 "longtitude": 5.209565
#             }
#         },
#         "visit_timestamp": "2024-06-19 09:54:20+00:00",
#         "driveTime": 11,
#         "distance": 0.647,
#         "nurse_latitude": 49.578164,
#         "nurse_longitude": 3.530603,
#         "patient_latitude": 51.474843,
#         "patient_longitude": 5.209565,
#         "service": "BATHING",
#         "visit_day": "2024-06-19",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 96205668770,
#         "rijksregisterNurse": 87968891759,
#         "visit": {
#             "id": 3788,
#             "visitAmounts": 5,
#             "duration": "THREE_MONTHS",
#             "service": "PHYSICAL_THERAPY",
#             "nurseLocation": {
#                 "latitude": 50.984381,
#                 "longtitude": 4.600268
#             },
#             "patientLocation": {
#                 "latitude": 50.605001,
#                 "longtitude": 5.018332
#             }
#         },
#         "visit_timestamp": "2024-10-05 19:30:20+00:00",
#         "driveTime": 5,
#         "distance": 3.223,
#         "nurse_latitude": 50.984381,
#         "nurse_longitude": 4.600268,
#         "patient_latitude": 50.605001,
#         "patient_longitude": 5.018332,
#         "service": "PHYSICAL_THERAPY",
#         "visit_day": "2024-10-05",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 22006669991,
#         "rijksregisterNurse": 98525016508,
#         "visit": {
#             "id": 9375,
#             "visitAmounts": 3,
#             "duration": "SIX_MONTHS",
#             "service": "ADMINISTER_MEDICATION",
#             "nurseLocation": {
#                 "latitude": 51.295046,
#                 "longtitude": 3.806934
#             },
#             "patientLocation": {
#                 "latitude": 49.551639,
#                 "longtitude": 2.545243
#             }
#         },
#         "visit_timestamp": "2024-03-20 06:19:16+00:00",
#         "driveTime": 38,
#         "distance": 1.084,
#         "nurse_latitude": 51.295046,
#         "nurse_longitude": 3.806934,
#         "patient_latitude": 49.551639,
#         "patient_longitude": 2.545243,
#         "service": "ADMINISTER_MEDICATION",
#         "visit_day": "2024-03-20",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 69193354151,
#         "rijksregisterNurse": 96759252358,
#         "visit": {
#             "id": 1099,
#             "visitAmounts": 2,
#             "duration": "TEN_MONTHS",
#             "service": "DENTAL_CARE",
#             "nurseLocation": {
#                 "latitude": 49.84502,
#                 "longtitude": 5.712924
#             },
#             "patientLocation": {
#                 "latitude": 51.027014,
#                 "longtitude": 5.001714
#             }
#         },
#         "visit_timestamp": "2024-10-19 09:17:59+00:00",
#         "driveTime": 11,
#         "distance": 1.283,
#         "nurse_latitude": 49.84502,
#         "nurse_longitude": 5.712924,
#         "patient_latitude": 51.027014,
#         "patient_longitude": 5.001714,
#         "service": "DENTAL_CARE",
#         "visit_day": "2024-10-19",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 73573136594,
#         "rijksregisterNurse": 73769434901,
#         "visit": {
#             "id": 2084,
#             "visitAmounts": 9,
#             "duration": "FOUR_MONTHS",
#             "service": "TEMPERATURE_MONITORING",
#             "nurseLocation": {
#                 "latitude": 51.32502,
#                 "longtitude": 3.794604
#             },
#             "patientLocation": {
#                 "latitude": 49.56167,
#                 "longtitude": 5.380152
#             }
#         },
#         "visit_timestamp": "2024-11-13 21:38:28+00:00",
#         "driveTime": 15,
#         "distance": 1.7229999999999999,
#         "nurse_latitude": 51.32502,
#         "nurse_longitude": 3.794604,
#         "patient_latitude": 49.56167,
#         "patient_longitude": 5.380152,
#         "service": "TEMPERATURE_MONITORING",
#         "visit_day": "2024-11-13",
#         "Fraud Risk": "Medium Risk"
#     },
#     {
#         "rijksregisterPatient": 87110134070,
#         "rijksregisterNurse": 16918613013,
#         "visit": {
#             "id": 2846,
#             "visitAmounts": 10,
#             "duration": "FIVE_MONTHS",
#             "service": "PHYSICAL_THERAPY",
#             "nurseLocation": {
#                 "latitude": 51.460999,
#                 "longtitude": 4.922274
#             },
#             "patientLocation": {
#                 "latitude": 51.371357,
#                 "longtitude": 4.366955
#             }
#         },
#         "visit_timestamp": "2024-12-12 20:15:55+00:00",
#         "driveTime": 24,
#         "distance": 4.936,
#         "nurse_latitude": 51.460999,
#         "nurse_longitude": 4.922274,
#         "patient_latitude": 51.371357,
#         "patient_longitude": 4.366955,
#         "service": "PHYSICAL_THERAPY",
#         "visit_day": "2024-12-12",
#         "Fraud Risk": "Medium Risk"
#     }
# ]
