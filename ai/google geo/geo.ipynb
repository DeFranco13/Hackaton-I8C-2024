# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt

# Data laden
data = pd.read_json('../../dataset.json')

# Voorbereiding van de features
X = data[['driveTime', 'distance']].values  

# Standaardisatie van de features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Definieer de parameter grid voor K-means
param_grid = {
    'n_clusters': range(2, 6),
    'n_init': [10, 20, 30, 40],
    'max_iter': [300, 400, 500]
}

# K-means model
kmeans = KMeans(random_state=42)

# Gebruik GridSearchCV voor hyperparameter optimalisatie
grid_search = GridSearchCV(kmeans, param_grid, cv=5, scoring='f1')
grid_search.fit(X_scaled)

# Beste model kiezen
best_kmeans = grid_search.best_estimator_
clusters = best_kmeans.predict(X_scaled)

# Afstanden van elk punt tot het clustercentrum berekenen
distances = best_kmeans.transform(X_scaled).min(axis=1)
distance_threshold_high = np.percentile(distances, 85)
distance_threshold_medium = np.percentile(distances, 60)

# Risiconiveaus toewijzen op basis van afstand en reistijd
data['Fraud Risk'] = np.where(distances >= distance_threshold_high, 'High Risk',
                             np.where(distances >= distance_threshold_medium, 'Medium Risk', 'Low Risk'))

# Simulatie van 'true labels' voor demonstratiedoeleinden
thresholds = data[['driveTime', 'distance']].quantile(0.85)
true_labels = ((data['driveTime'] > thresholds['driveTime']) | 
               (data['distance'] > thresholds['distance'])).astype(int)
predicted_labels = data['Fraud Risk'].apply(lambda x: 1 if x != 'Low Risk' else 0)

# Prestatiemetingen
accuracy = accuracy_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

print(f'Accuracy: {accuracy:.2f}')
print(f'Recall: {recall:.2f}')
print(f'Precision: {precision:.2f}')
print(f'F1 Score: {f1:.2f}')

# Confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
fig, ax = plt.subplots()
cax = ax.matshow(cm, cmap=plt.cm.Blues)
fig.colorbar(cax)
ax.set_xlabel('Predicted')
ax.set_ylabel('True')
ax.set_xticklabels(['', 'Low Risk', 'Medium/High Risk'])
ax.set_yticklabels(['', 'Low Risk', 'Medium/High Risk'])
plt.show()

# Filter en toon records die geclassificeerd zijn als 'High Risk' en 'Medium Risk'
high_risk_records = data[data['Fraud Risk'] == 'High Risk']
medium_risk_records = data[data['Fraud Risk'] == 'Medium Risk']
low_risk_records = data[data['Fraud Risk'] == 'Low Risk']

print("Records die hoogstwaarschijnlijk fraude zijn (High Risk):")
print(high_risk_records)
print("Records die mogelijk fraude zijn (Medium Risk):")
print(medium_risk_records)

# Tel het aantal records in elke risicocategorie
high_risk_count = high_risk_records.shape[0]
medium_risk_count = medium_risk_records.shape[0]
low_risk_count = low_risk_records.shape[0]

print(f"Aantal 'High Risk' records: {high_risk_count}")
print(f"Aantal 'Medium Risk' records: {medium_risk_count}")
print(f"Aantal 'Low Risk' records: {low_risk_count}")

# Exporteer de 'High Risk' en 'Medium Risk' records naar een JSON-object
high_risk_records_json = high_risk_records.to_json(orient='records', lines=True)
medium_risk_records_json = medium_risk_records.to_json(orient='records', lines=True)
print("JSON Output van hoogstwaarschijnlijke fraude records (High Risk):")
print(high_risk_records_json)
print("JSON Output van mogelijk frauduleuze records (Medium Risk):")
print(medium_risk_records_json)

# Visualisatie van de clusters
plt.scatter(data['driveTime'], data['distance'], c=data['Fraud Risk'].map({'Low Risk': 'green', 'Medium Risk': 'yellow', 'High Risk': 'red'}))
plt.xlabel('Drive Time')
plt.ylabel('Distance')
plt.colorbar()
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...
# {"rijksregisterPatient":44875409490,"rijksregisterNurse":75634229650,"visit":{"id":5710,"visitAmounts":5,"duration":"EIGHT_MONTHS","service":"NUTRITIONAL_SUPPORT","nurseLocation":{"latitude":51.291499,"longtitude":5.18207},"patientLocation":{"latitude":49.564861,"longtitude":4.7917}},"visit_timestamp":"2024-06-29T22:16:51Z","driveTime":11,"distance":0.892,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":36264685963,"rijksregisterNurse":32356853406,"visit":{"id":9249,"visitAmounts":1,"duration":"THREE_MONTHS","service":"PHYSICAL_THERAPY","nurseLocation":{"latitude":50.165971,"longtitude":4.194553},"patientLocation":{"latitude":49.531771,"longtitude":5.719526}},"visit_timestamp":"2024-07-01T07:14:52Z","driveTime":12,"distance":0.708,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":35532478613,"rijksregisterNurse":43896281023,"visit":{"id":1843,"visitAmounts":5,"duration":"EIGHT_MONTHS","service":"WALKING_ASSISTANCE","nurseLocation":{"latitude":49.898073,"longtitude":4.759158},"patientLocation":{"latitude":50.313206,"longtitude":2.500158}},"visit_timestamp":"2024-07-15T16:38:18Z","driveTime":19,"distance":4.634,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":23832172071,"rijksregisterNurse":85223299317,"visit":{"id":1260,"visitAmounts":6,"duration":"TWO_MONTHS","service":"VITAL_SIGN_MONITORING","nurseLocation":{"latitude":50.303749,"longtitude":3.503281},"patientLocation":{"latitude":49.803563,"longtitude":3.815308}},"visit_timestamp":"2024-07-17T14:13:48Z","driveTime":46,"distance":0.597,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":11983991987,"rijksregisterNurse":62392895263,"visit":{"id":9582,"visitAmounts":6,"duration":"NINE_MONTHS","service":"ADMINISTER_MEDICATION","nurseLocation":{"latitude":49.846554,"longtitude":5.163116},"patientLocation":{"latitude":50.579702,"longtitude":4.254842}},"visit_timestamp":"2024-08-04T17:59:46Z","driveTime":53,"distance":2.074,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":97525050662,"rijksregisterNurse":86719021925,"visit":{"id":7695,"visitAmounts":7,"duration":"FOUR_MONTHS","service":"ADMINISTER_MEDICATION","nurseLocation":{"latitude":50.433016,"longtitude":3.135779},"patientLocation":{"latitude":50.084619,"longtitude":2.829942}},"visit_timestamp":"2024-10-13T15:04:33Z","driveTime":11,"distance":1.172,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":27085956730,"rijksregisterNurse":33162880917,"visit":{"id":2752,"visitAmounts":2,"duration":"ONE_MONTH","service":"FEEDING_ASSISTANCE","nurseLocation":{"latitude":51.226201,"longtitude":3.195302},"patientLocation":{"latitude":50.92718,"longtitude":2.776155}},"visit_timestamp":"2024-02-08T14:27:11Z","driveTime":56,"distance":3.037,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":19972011771,"rijksregisterNurse":16533803679,"visit":{"id":1645,"visitAmounts":10,"duration":"FIVE_MONTHS","service":"PHYSICAL_THERAPY","nurseLocation":{"latitude":50.073742,"longtitude":3.910915},"patientLocation":{"latitude":50.785063,"longtitude":4.534642}},"visit_timestamp":"2024-10-02T09:46:17Z","driveTime":21,"distance":4.894,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":26789575380,"rijksregisterNurse":72701103767,"visit":{"id":2444,"visitAmounts":4,"duration":"TWELVE_MONTHS","service":"WALKING_ASSISTANCE","nurseLocation":{"latitude":50.02636,"longtitude":5.846682},"patientLocation":{"latitude":50.786511,"longtitude":3.703894}},"visit_timestamp":"2024-08-12T13:48:49Z","driveTime":11,"distance":0.716,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":81385949655,"rijksregisterNurse":51311401400,"visit":{"id":4275,"visitAmounts":1,"duration":"TWO_MONTHS","service":"NUTRITIONAL_SUPPORT","nurseLocation":{"latitude":50.448903,"longtitude":2.554819},"patientLocation":{"latitude":51.340939,"longtitude":4.239683}},"visit_timestamp":"2024-03-08T13:31:49Z","driveTime":21,"distance":4.97,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":44962369603,"rijksregisterNurse":35876187097,"visit":{"id":8943,"visitAmounts":5,"duration":"TEN_MONTHS","service":"WALKING_ASSISTANCE","nurseLocation":{"latitude":51.095493,"longtitude":3.141291},"patientLocation":{"latitude":51.032472,"longtitude":3.243983}},"visit_timestamp":"2024-12-25T12:35:44Z","driveTime":16,"distance":4.545,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":18190179815,"rijksregisterNurse":78740022686,"visit":{"id":4990,"visitAmounts":6,"duration":"NINE_MONTHS","service":"TEMPERATURE_MONITORING","nurseLocation":{"latitude":50.286593,"longtitude":4.746736},"patientLocation":{"latitude":50.454007,"longtitude":5.899819}},"visit_timestamp":"2024-10-06T08:04:54Z","driveTime":47,"distance":1.155,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":49075529944,"rijksregisterNurse":51334777436,"visit":{"id":9823,"visitAmounts":7,"duration":"ONE_MONTH","service":"PHYSICAL_THERAPY","nurseLocation":{"latitude":50.9223,"longtitude":5.7332},"patientLocation":{"latitude":49.594199,"longtitude":3.565799}},"visit_timestamp":"2024-03-06T22:47:35Z","driveTime":56,"distance":4.456,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":10171918673,"rijksregisterNurse":56119129634,"visit":{"id":4387,"visitAmounts":2,"duration":"FOUR_MONTHS","service":"WALKING_ASSISTANCE","nurseLocation":{"latitude":51.034826,"longtitude":3.173411},"patientLocation":{"latitude":49.549217,"longtitude":4.733263}},"visit_timestamp":"2024-03-31T09:14:25Z","driveTime":59,"distance":4.153,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":88679428731,"rijksregisterNurse":83852118185,"visit":{"id":9411,"visitAmounts":7,"duration":"TWELVE_MONTHS","service":"BATHING","nurseLocation":{"latitude":51.285646,"longtitude":3.321732},"patientLocation":{"latitude":51.279607,"longtitude":5.464496}},"visit_timestamp":"2024-11-28T19:21:23Z","driveTime":58,"distance":4.091,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":96693820528,"rijksregisterNurse":46032975449,"visit":{"id":1009,"visitAmounts":10,"duration":"TWO_MONTHS","service":"FEEDING_ASSISTANCE","nurseLocation":{"latitude":50.536546,"longtitude":3.100048},"patientLocation":{"latitude":51.215805,"longtitude":3.261392}},"visit_timestamp":"2024-08-03T08:23:57Z","driveTime":52,"distance":2.984,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":43891055827,"rijksregisterNurse":46591260595,"visit":{"id":2383,"visitAmounts":4,"duration":"NINE_MONTHS","service":"NUTRITIONAL_SUPPORT","nurseLocation":{"latitude":49.984049,"longtitude":5.767109},"patientLocation":{"latitude":49.777912,"longtitude":4.895472}},"visit_timestamp":"2024-02-20T19:03:08Z","driveTime":50,"distance":1.9,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":31147679556,"rijksregisterNurse":12805432662,"visit":{"id":2896,"visitAmounts":3,"duration":"ONE_MONTH","service":"DENTAL_CARE","nurseLocation":{"latitude":50.239511,"longtitude":3.281023},"patientLocation":{"latitude":50.949877,"longtitude":3.796813}},"visit_timestamp":"2024-02-06T20:53:19Z","driveTime":17,"distance":3.875,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":14327088869,"rijksregisterNurse":93277657030,"visit":{"id":7150,"visitAmounts":10,"duration":"TWO_MONTHS","service":"ADMINISTER_MEDICATION","nurseLocation":{"latitude":50.693655,"longtitude":5.150184},"patientLocation":{"latitude":51.401209,"longtitude":4.321194}},"visit_timestamp":"2024-01-28T22:33:42Z","driveTime":9,"distance":1.502,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":21452622987,"rijksregisterNurse":61085557295,"visit":{"id":1399,"visitAmounts":2,"duration":"EIGHT_MONTHS","service":"NUTRITIONAL_SUPPORT","nurseLocation":{"latitude":50.104814,"longtitude":5.927071},"patientLocation":{"latitude":50.991385,"longtitude":3.452182}},"visit_timestamp":"2024-08-26T15:34:03Z","driveTime":47,"distance":0.828,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":41891659521,"rijksregisterNurse":46599077761,"visit":{"id":5078,"visitAmounts":10,"duration":"ONE_MONTH","service":"ADMINISTER_MEDICATION","nurseLocation":{"latitude":50.93721,"longtitude":5.797905},"patientLocation":{"latitude":50.084782,"longtitude":5.100953}},"visit_timestamp":"2024-05-12T18:53:35Z","driveTime":13,"distance":1.397,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":27572255877,"rijksregisterNurse":18794342679,"visit":{"id":5744,"visitAmounts":6,"duration":"FIVE_MONTHS","service":"PHYSICAL_THERAPY","nurseLocation":{"latitude":50.066818,"longtitude":4.248508},"patientLocation":{"latitude":51.150433,"longtitude":2.805722}},"visit_timestamp":"2024-07-18T13:24:10Z","driveTime":55,"distance":4.182,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":96541970549,"rijksregisterNurse":91196302033,"visit":{"id":9075,"visitAmounts":3,"duration":"THREE_MONTHS","service":"BATHING","nurseLocation":{"latitude":49.731601,"longtitude":4.77536},"patientLocation":{"latitude":50.124191,"longtitude":2.801477}},"visit_timestamp":"2024-06-23T22:01:08Z","driveTime":7,"distance":1.578,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":65152375272,"rijksregisterNurse":13569417429,"visit":{"id":3153,"visitAmounts":5,"duration":"TWELVE_MONTHS","service":"FEEDING_ASSISTANCE","nurseLocation":{"latitude":51.432502,"longtitude":4.048662},"patientLocation":{"latitude":49.721677,"longtitude":5.175323}},"visit_timestamp":"2024-08-17T12:37:54Z","driveTime":55,"distance":3.94,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":71227537821,"rijksregisterNurse":27664418093,"visit":{"id":4714,"visitAmounts":2,"duration":"ONE_MONTH","service":"VITAL_SIGN_MONITORING","nurseLocation":{"latitude":51.177156,"longtitude":3.466804},"patientLocation":{"latitude":50.530728,"longtitude":4.188191}},"visit_timestamp":"2024-07-27T10:27:21Z","driveTime":58,"distance":4.778,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":86879302331,"rijksregisterNurse":96299584457,"visit":{"id":7725,"visitAmounts":2,"duration":"FIVE_MONTHS","service":"WALKING_ASSISTANCE","nurseLocation":{"latitude":49.553341,"longtitude":5.032023},"patientLocation":{"latitude":51.340062,"longtitude":3.747894}},"visit_timestamp":"2024-10-05T12:34:03Z","driveTime":18,"distance":2.87,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":57456621013,"rijksregisterNurse":11023552998,"visit":{"id":8781,"visitAmounts":4,"duration":"TWO_MONTHS","service":"DENTAL_CARE","nurseLocation":{"latitude":51.149841,"longtitude":2.539233},"patientLocation":{"latitude":50.614269,"longtitude":4.495397}},"visit_timestamp":"2024-06-08T20:14:37Z","driveTime":15,"distance":3.812,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":76239111875,"rijksregisterNurse":55012647353,"visit":{"id":5720,"visitAmounts":10,"duration":"NINE_MONTHS","service":"NUTRITIONAL_SUPPORT","nurseLocation":{"latitude":49.83345,"longtitude":2.980507},"patientLocation":{"latitude":49.703679,"longtitude":5.213509}},"visit_timestamp":"2024-03-11T13:02:38Z","driveTime":15,"distance":0.919,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":13023174354,"rijksregisterNurse":45138719422,"visit":{"id":3009,"visitAmounts":3,"duration":"TWELVE_MONTHS","service":"FEEDING_ASSISTANCE","nurseLocation":{"latitude":50.953158,"longtitude":5.1802},"patientLocation":{"latitude":51.414325,"longtitude":5.514546}},"visit_timestamp":"2024-11-25T06:05:57Z","driveTime":49,"distance":1.416,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":91518669872,"rijksregisterNurse":55207529502,"visit":{"id":1795,"visitAmounts":3,"duration":"THREE_MONTHS","service":"PHYSICAL_THERAPY","nurseLocation":{"latitude":50.211244,"longtitude":4.260776},"patientLocation":{"latitude":50.852208,"longtitude":5.078163}},"visit_timestamp":"2024-06-14T15:38:57Z","driveTime":58,"distance":4.631,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":41440238788,"rijksregisterNurse":38453983537,"visit":{"id":3977,"visitAmounts":10,"duration":"TEN_MONTHS","service":"FEEDING_ASSISTANCE","nurseLocation":{"latitude":49.96269,"longtitude":4.209723},"patientLocation":{"latitude":51.071753,"longtitude":4.507417}},"visit_timestamp":"2024-06-29T08:11:36Z","driveTime":18,"distance":4.651,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":63462304540,"rijksregisterNurse":79469345317,"visit":{"id":2369,"visitAmounts":8,"duration":"FIVE_MONTHS","service":"NUTRITIONAL_SUPPORT","nurseLocation":{"latitude":50.579149,"longtitude":4.686697},"patientLocation":{"latitude":50.21293,"longtitude":2.683133}},"visit_timestamp":"2024-06-16T15:16:11Z","driveTime":22,"distance":4.984,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":27698127671,"rijksregisterNurse":38114414290,"visit":{"id":4133,"visitAmounts":6,"duration":"NINE_MONTHS","service":"NUTRITIONAL_SUPPORT","nurseLocation":{"latitude":51.329602,"longtitude":4.783189},"patientLocation":{"latitude":51.313626,"longtitude":4.599553}},"visit_timestamp":"2024-12-27T19:40:21Z","driveTime":50,"distance":2.922,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":67275553792,"rijksregisterNurse":35561885726,"visit":{"id":6353,"visitAmounts":2,"duration":"TWELVE_MONTHS","service":"FEEDING_ASSISTANCE","nurseLocation":{"latitude":50.650786,"longtitude":2.569349},"patientLocation":{"latitude":50.338101,"longtitude":4.704464}},"visit_timestamp":"2024-01-05T13:20:37Z","driveTime":58,"distance":3.535,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":22254655189,"rijksregisterNurse":93987838618,"visit":{"id":6703,"visitAmounts":9,"duration":"TEN_MONTHS","service":"DENTAL_CARE","nurseLocation":{"latitude":51.255168,"longtitude":4.745402},"patientLocation":{"latitude":51.246847,"longtitude":3.300253}},"visit_timestamp":"2024-09-23T22:36:49Z","driveTime":59,"distance":4.096,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":57077890356,"rijksregisterNurse":35856315097,"visit":{"id":4759,"visitAmounts":7,"duration":"THREE_MONTHS","service":"ADMINISTER_MEDICATION","nurseLocation":{"latitude":50.796914,"longtitude":3.836029},"patientLocation":{"latitude":49.569775,"longtitude":2.540926}},"visit_timestamp":"2024-09-07T16:28:49Z","driveTime":11,"distance":2.496,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":53336886551,"rijksregisterNurse":24380394988,"visit":{"id":9212,"visitAmounts":4,"duration":"EIGHT_MONTHS","service":"VITAL_SIGN_MONITORING","nurseLocation":{"latitude":51.170082,"longtitude":5.26091},"patientLocation":{"latitude":49.916317,"longtitude":2.78992}},"visit_timestamp":"2024-10-21T19:43:25Z","driveTime":11,"distance":1.946,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":70436645270,"rijksregisterNurse":74343692336,"visit":{"id":6496,"visitAmounts":2,"duration":"THREE_MONTHS","service":"VITAL_SIGN_MONITORING","nurseLocation":{"latitude":50.419359,"longtitude":4.061676},"patientLocation":{"latitude":50.430942,"longtitude":2.997473}},"visit_timestamp":"2024-10-25T14:28:26Z","driveTime":19,"distance":4.36,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":39992427172,"rijksregisterNurse":41816607226,"visit":{"id":6707,"visitAmounts":2,"duration":"FOUR_MONTHS","service":"VITAL_SIGN_MONITORING","nurseLocation":{"latitude":50.920607,"longtitude":5.130547},"patientLocation":{"latitude":50.355538,"longtitude":2.924967}},"visit_timestamp":"2024-05-16T10:50:19Z","driveTime":10,"distance":1.323,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":59771698466,"rijksregisterNurse":47246744105,"visit":{"id":7472,"visitAmounts":1,"duration":"FOUR_MONTHS","service":"BATHING","nurseLocation":{"latitude":49.578164,"longtitude":3.530603},"patientLocation":{"latitude":51.474843,"longtitude":5.209565}},"visit_timestamp":"2024-06-19T09:54:20Z","driveTime":11,"distance":0.647,"Fraud Risk":"Medium Risk"}
# {"rijksregisterPatient":69193354151,"rijksregisterNurse":96759252358,"visit":{"id":1099,"visitAmounts":2,"duration":"TEN_MONTHS","service":"DENTAL_CARE","nurseLocation":{"latitude":49.84502,"longtitude":5.712924},"patientLocation":{"latitude":51.027014,"longtitude":5.001714}},"visit_timestamp":"2024-10-19T09:17:59Z","driveTime":11,"distance":1.283,"Fraud Risk":"Medium Risk"}
